# %%
import numpy as np

f = open("../build/doclens.bin", "rb")
n = np.fromfile(f, dtype=np.int32, count=1)[0]
data = np.fromfile(f, dtype=np.int32, count=n)

# %%
n
# Out:
# np.int32(2428854)

# %%
import matplotlib.pyplot as plt

# plot the distribution of data
plt.hist(data, bins=50)
# Out:
# (array([4.16000e+02, 4.05500e+03, 8.48400e+03, 1.71430e+04, 1.72380e+04,
#         2.84150e+04, 2.58460e+04, 3.85560e+04, 3.16580e+04, 4.52680e+04,
#         3.55070e+04, 4.91260e+04, 5.01500e+04, 3.79260e+04, 5.12890e+04,
#         3.84910e+04, 5.08050e+04, 3.81060e+04, 5.06900e+04, 3.73220e+04,
#         4.95510e+04, 3.66790e+04, 4.86580e+04, 3.61780e+04, 4.80880e+04,
#         4.73270e+04, 3.54410e+04, 4.70430e+04, 3.50760e+04, 4.65740e+04,
#         3.50510e+04, 4.69650e+04, 3.53340e+04, 4.82210e+04, 3.68680e+04,
#         5.09380e+04, 4.04370e+04, 5.84530e+04, 6.69220e+04, 6.00460e+04,
#         1.02797e+05, 1.04136e+05, 1.82911e+05, 1.58259e+05, 1.83928e+05,
#         8.22920e+04, 4.06380e+04, 6.50500e+03, 1.02500e+03, 2.20000e+01]),
#  array([  3.  ,   6.54,  10.08,  13.62,  17.16,  20.7 ,  24.24,  27.78,
#          31.32,  34.86,  38.4 ,  41.94,  45.48,  49.02,  52.56,  56.1 ,
#          59.64,  63.18,  66.72,  70.26,  73.8 ,  77.34,  80.88,  84.42,
# ...
